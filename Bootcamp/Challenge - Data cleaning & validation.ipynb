# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir('C:\\Users\\mhuh22\\Desktop\\Thinkful\\Unit_1\\3. Intermediate Visualization\\')
journals= pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding='latin1')

# %%
journals
# Out:
#                             PMID/PMCID  \
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 22            PMCID:\n    PMC3656742\n
# 23                      PMCID: 3584654
# 24                 22971149 PMC3466778
# ...

# %%
for column in journals:
    print(journals['{}'.format(column)].unique())
    print("")
# Out:
# [nan 'PMC3679557' '23043264  PMC3506128 ' ... '3748854' '3785148'
#  'PMID: 23846567  (Epub July 2013)']
#
# ['CUP' 'ACS' 'ACS (Amercian Chemical Society) Publications'
#  'ACS Publications' 'AGA Institute' 'AMBSB'
#  'American Association of Immunologists' 'American Chemical Society'
#  'AMERICAN CHEMICAL SOCIETY' 'American Chemical Society Publications'
#  'American College of Chest Physicians' 'American Physiological Society'
#  'American Psychiatric Association' 'American Psychiatric Publishing'
#  'American Psychological Association'
#  'American Psychological Association '
#  'American Public Health Association'
#  'American Soc for Biochemistry and Molecular Biology'
#  'American Society for Biochemistry and Molecular Biolgy'
#  'American Society for Biochemistry and Molecular Biology'
#  'American Society for Biochemistry and Molecular Biology '
#  'American Society for Investigative Pathology'
#  'American Society for Microbiology' 'American Society for Microbiology '
# ...

# %%
# drop rows with na values
journals = journals.dropna()

# capitaize journal names
journals['Journal title'] = journals['Journal title'].apply(lambda x: str(x).capitalize())

# abbreviate 'cost' column
journals = journals.rename(columns={'COST (£) charged to Wellcome (inc VAT when charged)': 'cost'})

# adds counter that will be used for counting journals
journals['count'] = 0

# %%
# count appearances of each journal
journal_count = journals[['Journal title','count']].groupby(['Journal title']).count()

# sort and return top 5 most common journals
(journal_count.sort_values(['count'], ascending=False)).head()
# Out:
#                                  count
# Journal title
# Plos one                           188
# Journal of biological chemistry     52
# Neuroimage                          28
# Plos pathogens                      24
# Plos genetics                       23

# %%
journals2 = journals[['Journal title', 'cost']]
#journals2.groupby('Journal title').mean()
journals2 = journals2['cost'].str.replace('£', '')
journals2
# Out:
# 1       2381.04
# 2        642.56
# 3        669.64
# 4        685.88
# 5       2392.20
# 6       2367.95
# 7        649.33
# 8       1294.59
# 9       1294.78
# 10      1329.69
# 11      1287.20
# 12      1324.66
# 13       665.64
# 14      1006.72
# 15       238.08
# 16       265.67
# 17      2035.00
# 18      3108.08
# 19      1267.76
# 20      2286.73
# 22      1186.80
# 23       642.89
# 24      1533.29
# 25      2082.74
# 26      2314.10
# 27       759.67
# 28      1565.26
# 29       572.74
# 30       750.66
# 31       321.12
#          ...
# 2097    2236.02
# 2098    2275.02
# 2099    2373.57
# 2100     791.19
# 2101    1551.49
# 2102    1961.68
# 2103    1982.35
# 2104    2239.22
# 2105    2377.65
# 2106    2272.15
# 2107    1900.70
# 2108    3026.17
# 2109    1851.15
# 2110    1812.89
# 2111    1816.70
# 2112    2168.05
# 2113    1409.96
# 2114    2400.00
# 2115    1968.63
# 2116    2015.72
# 2117    1836.92
# 2118    1836.92
# 2119    1375.80
# 2120    1836.92
# ...
