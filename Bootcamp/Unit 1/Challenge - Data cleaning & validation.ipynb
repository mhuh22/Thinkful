# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir('C:\\Users\\mhuh22\\Desktop\\Thinkful\\Unit_1\\3. Intermediate Visualization\\')
journals= pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding='latin1')

# %%
journals.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# 4                                            £685.88

# %%
# returns unique values for each column
#for column in journals:
#    print(journals['{}'.format(column)].unique())
#    print("")

# %%
# cleaning up the data

# drop rows with na values
journals = journals.dropna()

# capitaize journal names
journals['Journal title'] = journals['Journal title'].apply(lambda x: str(x).capitalize())

# cleaning up publisher section
journals['Publisher'] = journals['Publisher'].str.replace('Publications','')
journals['Publisher'] = journals['Publisher'].str.strip()
journals['Publisher'] = journals['Publisher'].str.replace(r'/|\(|\)|','')

# abbreviate 'cost' column
journals = journals.rename(columns={'COST (£) charged to Wellcome (inc VAT when charged)': 'cost'})

# deletes currency symbols and converts the cost into a manipulable float
journals['cost'] = journals['cost'].str.replace(r'£|\$','',).astype(float)

# removes rows where the cost is 999999. which clearly is bad data
journals = journals[journals.cost != 999999.00]

# adds counter that will be used for counting journals
journals['count'] = 0

# %%
# count appearances of each journal
journal_count = journals[['Journal title','count']].groupby(['Journal title']).count()

# sort and return top 5 most common journals
(journal_count.sort_values(['count'], ascending=False)).head()
# Out:
#                                  count
# Journal title
# Plos one                           181
# Journal of biological chemistry     51
# Neuroimage                          28
# Plos genetics                       22
# Nucleic acids research              22

# %%
journals.groupby(['Publisher']).mean()
# Out:
#                                                            cost  count
# Publisher
# ACS                                                 1273.440000      0
# ACS Amercian Chemical Society                       1306.184000      0
# AGA Institute                                        238.080000      0
# AMBSB                                                265.670000      0
# AMERICAN CHEMICAL SOCIETY                            642.890000      0
# ASBMB                                               1450.640227      0
# ASBMB Cadmus                                         381.040000      0
# ASBMBCadmus                                          938.750000      0
# ASBMBCenveo Publisher Services                      1188.390000      0
# ASBMC CENVEO                                        1055.070000      0
# ASM                                                 1715.665000      0
# ASM American Society for Microbiology               1299.390000      0
# American Association of Immunologists               2571.540000      0
# American Chemical Society                           1305.877143      0
# American College of Chest Physicians                2383.940000      0
# American Physiological Society                      1363.344286      0
# American Psychiatric Publishing                     2350.020000      0
# American Psychological Association                  2905.475000      0
# American Public Health Association                  1422.250000      0
# American Soc for Biochemistry and Molecular Bio...  1100.000000      0
# American Society for Biochemistry and Molecular...  2259.640000      0
# American Society for Biochemistry and Molecular...  1345.844737      0
# American Society for Investigative Pathology         995.310000      0
# American Society for Microbiology                   1797.527059      0
# American Society of Hamatology                      1597.980000      0
# American Society of Hematology                      1455.592000      0
# American Society of Human Genetics Elsevier         2181.090000      0
# American Society of Microbiology                    1543.923333      0
# Association for Research in Vision & Ophthalmology  1157.880000      0
# BMC                                                 1304.428182      0
# ...                                                         ...    ...
# The Company of Biologists                           2010.000000      0
# The Company of Biologists Ltd                       1620.000000      0
# The Endocrine Socety                                1875.000000      0
# The Endocrine Society                               2129.218571      0
# The Royal College of Psychiatrists                  3000.000000      0
# The Royal Society                                   1672.963333      0
# The Sheridan Press                                   975.970000      0
# The company of Biolgists                            1722.000000      0
# The company of Biologists                           1044.000000      0
# The royal Society                                   1680.000000      0
# University of the Basque Country Press              1306.110000      0
# WileyBlackwell                                      1513.730      0
# Wliey-Blackwell                                     2400.000      0
# Wolters Kluwer                                      1836.920      0
# Wolters Kluwer Health                               1834.770      0
# Wolters Kluwer N.V.Lippinott                        2374.520      0
# Wolters Kluwers                                     2034.750      0
# public.service.co.uk                                6000.000      0
#
# [243 rows x 2 columns]

# %%
journals.groupby(['Publisher']).std()
# Out:
#                                                             cost  count
# Publisher
# ACS                                                   837.722977    0.0
# ACS Amercian Chemical Society                          19.485629    0.0
# AGA Institute                                                NaN    NaN
# AMBSB                                                        NaN    NaN
# AMERICAN CHEMICAL SOCIETY                                    NaN    NaN
# ASBMB                                                 311.998692    0.0
# ASBMB Cadmus                                                 NaN    NaN
# ASBMBCadmus                                                  NaN    NaN
# ASBMBCenveo Publisher Services                               NaN    NaN
# ASBMC CENVEO                                                 NaN    NaN
# ASM                                                   263.220499    0.0
# ASM American Society for Microbiology                        NaN    NaN
# American Association of Immunologists                 758.782145    0.0
# American Chemical Society                             639.022079    0.0
# American College of Chest Physicians                         NaN    NaN
# American Physiological Society                        117.577249    0.0
# American Psychiatric Publishing                              NaN    NaN
# American Psychological Association                    275.989046    0.0
# American Public Health Association                           NaN    NaN
# American Soc for Biochemistry and Molecular Bio...           NaN    NaN
# American Society for Biochemistry and Molecular...           NaN    NaN
# American Society for Biochemistry and Molecular...    367.725909    0.0
# American Society for Investigative Pathology                 NaN    NaN
# American Society for Microbiology                     654.376194    0.0
# American Society of Hamatology                               NaN    NaN
# American Society of Hematology                        131.494304    0.0
# American Society of Human Genetics Elsevier                  NaN    NaN
# American Society of Microbiology                      416.333955    0.0
# Association for Research in Vision & Ophthalmology           NaN    NaN
# BMC                                                   249.249029    0.0
# ...                                                          ...    ...
# The Company of Biologists                             551.543289    0.0
# The Company of Biologists Ltd                                NaN    NaN
# The Endocrine Socety                                         NaN    NaN
# The Endocrine Society                                 206.415860    0.0
# The Royal College of Psychiatrists                      0.000000    0.0
# The Royal Society                                     252.515600    0.0
# The Sheridan Press                                    249.651120    0.0
# The company of Biolgists                              958.836795    0.0
# The company of Biologists                                    NaN    NaN
# The royal Society                                            NaN    NaN
# University of the Basque Country Press                       NaN    NaN
# Wiley                                               18328.730080    0.0
# Wiley & Son                                                  NaN    NaN
# Wiley Blackwell                                        70.476507    0.0
# Wiley Online Library                                         NaN    NaN
# Wiley Subscription Services                           318.462736    0.0
# Wiley Subscription Services  Inc.                       7.829593    0.0
# Wiley Subscription Services Inc                       639.740718    0.0
# Wiley Subscription Serviices Inc                             NaN    NaN
# Wiley VCH                                                    NaN    NaN
# Wiley-Blackwell                                       275.376208    0.0
# Wiley-Blackwell, John Wiley & Sons                           NaN    NaN
# Wiley-VCH                                             551.176258    0.0
# WileyBlackwell                                               NaN    NaN
# Wliey-Blackwell                                              NaN    NaN
# Wolters Kluwer                                        220.497306    0.0
# Wolters Kluwer Health                                 289.033092    0.0
# Wolters Kluwer N.V.Lippinott                                 NaN    NaN
# Wolters Kluwers                                              NaN    NaN
# public.service.co.uk                                         NaN    NaN
#
# [243 rows x 2 columns]
